# %% [markdown]
# # 🔥 Heatmap - Accessibilité aux médecins (France entière)
#
# Visualisation rapide et légère avec heatmap (sans info-bulles)

# %% [markdown]
# ## 📦 Imports

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
import matplotlib.pyplot as plt
from pathlib import Path

print("✅ Imports OK")
# Out:
# ✅ Imports OK

# %% [markdown]
# ## 📥 Chargement des données

# %%
# Charger IRIS France entière
print("📥 Chargement des IRIS...")
gdf_iris = gpd.read_file("../data/geo/iris_france.gpkg")

print(f"✅ {len(gdf_iris):,} IRIS chargés")
# Out:
# 📥 Chargement des IRIS...
# ✅ 48,512 IRIS chargés

# %%
file_name = "apl_medecins_generalistes.xlsx"
# PATHS
data_path = Path("/Users/jean-jacques/code/jjchabutDataCRM/sante-territoires/data/raw/offres_soins")

full_path = data_path / file_name

xl = pd.ExcelFile(full_path)
print(f'Sheet du fichier : {xl.sheet_names}')

# 1. Charger l'onglet APL 2023 
# On saute les 8 premières lignes pour arriver aux noms de colonnes (Code commune, etc.)
df_2023 = pd.read_excel(
    full_path, 
    sheet_name='APL 2023', 
    skiprows=8,
    dtype={'Code commune': str} # Important pour garder les "0" au début des codes postaux/Insee
)

# 2. Charger l'onglet Paramètres
# Les données de pondération commencent à la ligne 21
df_params = pd.read_excel(
    full_path, 
    sheet_name='Paramètres', 
    skiprows=21
)
# Out:
# Sheet du fichier : ['Paramètres', 'APL 2022', 'APL 2023']

# %% [markdown]
# ## 🔗 Jointure IRIS + APL

# %%
# Jointure
gdf_final = gdf_iris.merge(
    df_2023,
    left_on='code_insee',
    right_on='Code commune INSEE',
    how='inner'  # Garder seulement les IRIS avec APL
)

print(f"✅ {len(gdf_final):,} IRIS avec APL")
# Out:
# ✅ 48,492 IRIS avec APL

# %% [markdown]
# ## 📍 Extraction des coordonnées

# %%
# Reprojeter en WGS84 pour obtenir lat/lon
print("🌍 Reprojection en WGS84...")
gdf_final_wgs84 = gdf_final.to_crs(epsg=4326)

# Extraire les coordonnées du centroïde de chaque IRIS
gdf_final_wgs84['longitude'] = gdf_final_wgs84.geometry.centroid.x
gdf_final_wgs84['latitude'] = gdf_final_wgs84.geometry.centroid.y

print("✅ Coordonnées extraites")
print("\n🔍 Aperçu :")
print(gdf_final_wgs84[['nom_commune', 'latitude', 'longitude']].head())
# Out:
# 🌍 Reprojection en WGS84...
# ✅ Coordonnées extraites
#
# 🔍 Aperçu :
#                    nom_commune   latitude  longitude
# 0                    Bischheim  48.632568   7.782758
# 1  Marseille 2e Arrondissement  43.324823   5.357664
# 2                       Quéven  47.769735  -3.442135
# 3                  Romainville  48.894659   2.433999
# 4             Marolles-en-Brie  48.748145   2.561351
# /var/folders/vr/hhxf111n55b91l_9j5qxjdrm0000gn/T/ipykernel_51931/2147017105.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_final_wgs84['longitude'] = gdf_final_wgs84.geometry.centroid.x
# /var/folders/vr/hhxf111n55b91l_9j5qxjdrm0000gn/T/ipykernel_51931/2147017105.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_final_wgs84['latitude'] = gdf_final_wgs84.geometry.centroid.y

# %% [markdown]
# ## 🔍 Identifier la colonne APL

# %%
# Trouver la colonne APL
apl_cols = [col for col in gdf_final_wgs84.columns if 'apl' in col.lower() or 'acces' in col.lower()]
print(f"🔍 Colonnes APL trouvées : {apl_cols}")

# ⚠️ ADAPTER si besoin
colonne_apl = apl_cols[0] if apl_cols else 'APL'
print(f"✅ Colonne sélectionnée : {colonne_apl}")
# Out:
# 🔍 Colonnes APL trouvées : ['APL aux médecins généralistes', 'APL aux médecins généralistes de 65 ans et moins ', 'APL aux médecins généralistes de 62 ans et moins ', 'APL aux médecins généralistes de 60 ans et moins ']
# ✅ Colonne sélectionnée : APL aux médecins généralistes

# %% [markdown]
# ## 🔥 Option 1 : Heatmap simple (déserts médicaux)

# %%
# Identifier les zones avec APL faible (déserts médicaux)
seuil_desert = 2.5  # À ajuster

deserts = gdf_final_wgs84[gdf_final_wgs84[colonne_apl] < seuil_desert]

print(f"🏜️ {len(deserts):,} IRIS en désert médical (APL < {seuil_desert})")
print(f"📊 Soit {len(deserts)/len(gdf_final_wgs84)*100:.1f}% des IRIS")
# Out:
# 🏜️ 13,968 IRIS en désert médical (APL < 2.5)
# 📊 Soit 28.8% des IRIS

# %%
# Créer la carte
m = folium.Map(
    location=[46.5, 2.5],  # Centre de la France
    zoom_start=6,
    tiles='CartoDB positron'
 )

# Préparer les données pour la heatmap
# Format : [[lat, lon, poids], ...]
heat_data = [
    [row['latitude'], row['longitude'], 1]  # Poids = 1 (intensité uniforme)
    for idx, row in deserts.iterrows()
 ]

# Ajouter la heatmap
HeatMap(
    heat_data,
    radius=15,           # Rayon de diffusion
    blur=20,             # Flou
    max_zoom=13,
    gradient={
        0.0: 'blue',
        0.5: 'yellow',
        1.0: 'red'
    }
 ).add_to(m)

# Titre
title_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; 
            background-color: white;
            border: 2px solid grey;
            border-radius: 5px;
            z-index: 9999;
            padding: 10px;
            box-shadow: 2px 2px 6px rgba(0,0,0,0.3);">
    <h4 style="margin: 0;">🔥 Déserts médicaux en France</h4>
    <p style="margin: 5px 0 0 0; font-size: 12px;">APL < 2.5</p>
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

print("✅ Heatmap créée")

# Essayer l'affichage direct Folium
m
# Out:
# ✅ Heatmap créée
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca75dcc467bb990e444db8f760ba85b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#             top: 10px; left: 50px;
#             background-color: white;
#             border: 2px solid grey;
#             border-radius: 5px;
#             z-index: 9999;
#             padding: 10px;
#             box-shadow: 2px 2px 6px rgba(0,0,0,0.3);&quot;&gt;
#     &lt;h4 style=&quot;margin: 0;&quot;&gt;🔥 Déserts médicaux en France&lt;/h4&gt;
#     &lt;p style=&quot;margin: 5px 0 0 0; font-size: 12px;&quot;&gt;APL &lt; 2.5&lt;/p&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca75dcc467bb990e444db8f760ba85b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca75dcc467bb990e444db8f760ba85b7 = L.map(
#                 &quot;map_ca75dcc467bb990e444db8f760ba85b7&quot;,
#                 {
#                     center: [46.5, 2.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fc4dac2bbee09744e1f08222a2411ab = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
# %%
# Carte avec intensité variable selon l'APL
m2 = folium.Map(
    location=[46.5, 2.5],
    zoom_start=6,
    tiles='CartoDB positron'
)

# Inverser l'APL pour que faible APL = forte intensité
max_apl = gdf_final_wgs84[colonne_apl].max()

heat_data_weighted = [
    [
        row['latitude'], 
        row['longitude'], 
        max_apl - row[colonne_apl]  # Poids inversé
    ]
    for idx, row in gdf_final_wgs84.iterrows()
    if pd.notna(row[colonne_apl])
]

# Ajouter la heatmap pondérée
HeatMap(
    heat_data_weighted,
    radius=12,
    blur=15,
    max_zoom=13,
    gradient={
        0.0: 'green',
        0.5: 'yellow',
        1.0: 'red'
    }
).add_to(m2)

# Titre
title2_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; 
            background-color: white;
            border: 2px solid grey;
            border-radius: 5px;
            z-index: 9999;
            padding: 10px;
            box-shadow: 2px 2px 6px rgba(0,0,0,0.3);">
    <h4 style="margin: 0;">🔥 Accessibilité aux médecins - France</h4>
    <p style="margin: 5px 0 0 0; font-size: 12px;">Rouge = Faible accessibilité</p>
</div>
'''
m2.get_root().html.add_child(folium.Element(title2_html))

print("✅ Heatmap pondérée créée")

# Afficher
m2
# Out:
# ✅ Heatmap pondérée créée
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_580d3ba1378e2084fa97de3dfa526d9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#             top: 10px; left: 50px;
#             background-color: white;
#             border: 2px solid grey;
#             border-radius: 5px;
#             z-index: 9999;
#             padding: 10px;
#             box-shadow: 2px 2px 6px rgba(0,0,0,0.3);&quot;&gt;
#     &lt;h4 style=&quot;margin: 0;&quot;&gt;🔥 Accessibilité aux médecins - France&lt;/h4&gt;
#     &lt;p style=&quot;margin: 5px 0 0 0; font-size: 12px;&quot;&gt;Rouge = Faible accessibilité&lt;/p&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_580d3ba1378e2084fa97de3dfa526d9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_580d3ba1378e2084fa97de3dfa526d9b = L.map(
#                 &quot;map_580d3ba1378e2084fa97de3dfa526d9b&quot;,
#                 {
#                     center: [46.5, 2.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2811c06ebc22f3887c1d2754aaa6d90 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2811c06ebc22f3887c1d2754aaa6d90.addTo(map_580d3ba1378e2084fa97de3dfa526d9b);
#
#
#             var heat_map_d8c4110e2d7fa64b3f35706dd9d4650d = L.heatLayer(
#                 [[48.632568119692166, 7.782757556699837, 36.286], [43.324822955061414, 5.357663996309815, 34.831], [47.769735078810534, -3.442134582844186, 34.276], [48.89465896903524, 2.433998634361015, 36.378], [48.74814466575182, 2.561350695070015, 37.837], [43.413122243070184, 5.355273507405667, 34.375], [48.98708024735561, 2.548064080923324, 37.972], [48.755037281703835, 2.334571159671013, 36.609], [45.78305096871933, 4.851576177748424, 35.347], [51.01826526808434, 2.2864105004303057, 36.791000000000004], [47.95076083634226, 1.9279775064900253, 36.879000000000005], [43.43392532618365, 5.215490427875807, 36.197], [45.73130381040452, 4.954105325184098, 36.799], [48.98154686922148, 2.1211193405604374, 38.038000000000004], [49.33843426375592, 6.154301060240443, 35.635000000000005], [49.29092946790053, 1.028636233854924, 36.370000000000005], [48.43001126145773, -4.458890226196146, 34.661], [43.297467601000925, 5.375102200403989, 33.673], [49.19295253884989, -0.2883052187153508, 34.521], [43.660214184174805, 7.196609154595799, 35.832], [44.897460428928746, -0.5611612070592175, 33.681], [51.01788503856214, 2.2020032736622945, 37.143], [43.55753748594951, 6.9482162868023805, 34.503], [43.603252642178575, 7.079745738950309, 35.129000000000005], [50.63209015492055, 3.0598900594159297, 33.927], [49.93180435690778, 2.2682532942262332, 33.973], [48.76254015750758, 2.3506062610856007, 37.733000000000004], [48.989669075106434, 2.3939102783189243, 37.732], [48.88493799343889, 2.480883191855046, 37.436], [48.97001392805569, 2.514580297396247, 37.913000000000004], [48.62452472800244, 7.783444470090609, 34.72], [48.54293531672781, 7.694805421654804, 34.658], [47.48000641800825, -0.49899385460944784, 34.132000000000005], [48.94301189522642, 2.4290005214398183, 37.791000000000004], [49.188958728380946, 6.7020842340489954, 36.751000000000005], [48.95814257028345, 2.372829474294964, 36.492000000000004], [50.96699158232414, 1.8881415444280722, 36.104], [47.9150680157424, 1.8818615060293387, 35.619], [45.203289655943415, 5.695985575711731, 35.812], [44.936359532446055, 4.89444359464893, 36.216], [49.026273094414925, 1.1407352525619499, 37.392], [45.76076073262276, 4.84329897221437, 35.392], [49.168957773620846, 6.163367535454349, 35.95], [49.31976069484161, 6.143412239792685, 35.212], [48.93326004004223, 1.8043507290993266, 36.947], [48.50575479335528, 7.70937561356714, 34.159], [45.71255664091623, 4.871201700032351, 35.291000000000004], [48.65221487927012, 6.139542183131622, 33.193], [48.16434643402783, -2.7555873494912135, 36.639], [47.19419166867326, -1.57164337628573, 34.426], [48.57306910032276, 2.1604260810017353, 38.111000000000004], [49.08067465055148, 6.140560142330308, 35.385000000000005], [48.61845812750369, 2.465656642376654, 38.050000000000004], [45.619418375257546, 0.10790203367724756, 36.47], [46.342268500159236, -0.38375152801160267, 36.001000000000005], [43.17542582593684, 2.7488217079338124, 36.660000000000004], [46.13615126507146, -1.1013679642092358, 32.537], [50.30048260097734, 4.107277254

# %% [markdown]
# ## 🔥 Option 3 : Heatmap par région

# %%
# Exemple : Heatmap des Hauts-de-France
gdf_hdf = gdf_final_wgs84[gdf_final_wgs84['code_insee'].astype(str).str.startswith(('02', '59', '60', '62', '80'))]

print(f"📍 {len(gdf_hdf):,} IRIS dans les Hauts-de-France")

# Centre sur Lille
m3 = folium.Map(
    location=[50.6, 3.0],
    zoom_start=8,
    tiles='CartoDB positron'
)

# Heatmap région
heat_data_hdf = [
    [row['latitude'], row['longitude'], max_apl - row[colonne_apl]]
    for idx, row in gdf_hdf.iterrows()
    if pd.notna(row[colonne_apl])
]

HeatMap(
    heat_data_hdf,
    radius=10,
    blur=12,
    max_zoom=13,
    gradient={'0.0': 'green', '0.5': 'yellow', '1.0': 'red'}
).add_to(m3)

# Titre
title3_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; 
            background-color: white;
            border: 2px solid grey;
            border-radius: 5px;
            z-index: 9999;
            padding: 10px;
            box-shadow: 2px 2px 6px rgba(0,0,0,0.3);">
    <h4 style="margin: 0;">🔥 Accessibilité - Hauts-de-France</h4>
</div>
'''
m3.get_root().html.add_child(folium.Element(title3_html))

print("✅ Heatmap Hauts-de-France créée")

m3
# Out:
# 📍 5,003 IRIS dans les Hauts-de-France
# ✅ Heatmap Hauts-de-France créée
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_
], [50.64242509796145, 3.0763014036716503, 33.927], [51.00885716375313, 2.3439136699166663, 36.424], [49.38941879945772, 2.788290424455517, 36.454], [49.42976766195244, 2.8487601628632735, 36.454], [49.90709034221381, 2.274572671379889, 33.973], [49.930253601194686, 2.2934021060854053, 33.973], [50.61864422064318, 3.0989619243208355, 33.927], [50.6226646081451, 3.108588202994002, 33.927], [50.636594329847604, 2.979131780008734, 33.927], [50.63728847528742, 2.9986311551803966, 33.927], [50.698794659912714, 2.8736952561390487, 36.06], [49.245935272887735, 2.893992300889219, 36.745000000000005], [50.35227432922656, 3.557450547185942, 33.928], [51.04591252643212, 2.336788293486831, 36.424], [50.76787264018978, 3.1048857271374817, 37.291000000000004], [50.38830813323067, 3.5431893454523924, 35.926], [50.406965765790815, 3.1040523779

# %% [markdown]
# ## 💾 Sauvegarder les cartes

# %%
# Sauvegarder (très rapide !)
m.save('../outputs/figures/heatmap_deserts_medicaux_france.html')
m2.save('../outputs/figures/heatmap_apl_france.html')
m3.save('../outputs/figures/heatmap_hauts_de_france.html')

print("✅ 3 cartes sauvegardées dans outputs/figures/")
print("⚡ Génération ultra-rapide !")
# Out:
# ✅ 3 cartes sauvegardées dans outputs/figures/
# ⚡ Génération ultra-rapide !

# %% [markdown]
# ## 📊 Stats rapides

# %%
# Stats par région (code département)
gdf_final_wgs84['dept'] = gdf_final_wgs84['code_insee'].astype(str).str[:2]

stats_dept = gdf_final_wgs84.groupby('dept')[colonne_apl].agg([
    ('APL moyen', 'mean'),
    ('APL min', 'min'),
    ('APL max', 'max'),
    ('Nb IRIS', 'count')
]).sort_values('APL moyen')

print("📊 Top 10 départements avec APL le plus faible :")
print(stats_dept.head(10))
# Out:
# 📊 Top 10 départements avec APL le plus faible :
#      APL moyen APL min APL max  Nb IRIS
# dept
# 18    1.931395   0.427   3.561      332
# 2B    2.027559     0.0  10.298      254
# 28    2.227772   0.779   4.434      416
# 77    2.232983   0.146   4.262      762
# 45    2.234948    0.34   4.805      444
# 48    2.242038     0.0  10.799      158
# 01    2.389038     0.0   5.045      447
# 58    2.390452     0.0   6.402      341
# 95    2.393241   1.033   4.592      561
# 07    2.415291     0.0   7.143      361

# %%
# Ouvrir la carte dans le navigateur automatiquement
import webbrowser
webbrowser.open('/Users/jean-jacques/code/jjchabutDataCRM/sante-territoires/outputs/figures/heatmap_deserts_medicaux_france.html')
# Out:
# True

# %%
# Heatmap Plotly interactive pour les déserts médicaux
import plotly.express as px
import pandas as pd

# Créer un DataFrame à partir des données des déserts
df_deserts = deserts[['latitude', 'longitude']].copy()
df_deserts['poids'] = 1  # Intensité uniforme

# Afficher la heatmap Plotly
fig = px.density_mapbox(
    df_deserts,
    lat='latitude',
    lon='longitude',
    z='poids',
    radius=15,
    center=dict(lat=46.5, lon=2.5),
    zoom=5,
    mapbox_style='carto-positron',
    title='Déserts médicaux en France (APL < 2.5)'
 )
fig.show()
# Out:
# /var/folders/vr/hhxf111n55b91l_9j5qxjdrm0000gn/T/ipykernel_51931/3486743948.py:10: DeprecationWarning: *density_mapbox* is deprecated! Use *density_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.density_mapbox(
